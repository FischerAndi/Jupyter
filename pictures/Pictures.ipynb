# %% [markdown]
# # Working with Pictures

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import skimage
import skimage.color as skic
import skimage.filters as skif
import skimage.data as skid
import skimage.util as sku
# %matplotlib inline

# %%
def show(img):
    fig, ax = plt.subplots(1, 1, figsize=(8, 8))
    ax.imshow(img, cmap=plt.cm.gray)
    ax.set_axis_off()
    plt.show()

# %%
image = mpimg.imread("sudoku.png")
plt.imshow(image)
plt.show()

# %%
from PIL import Image

try:
    with Image.open('sudoku.png') as im:
        print(im.format, "%d x %d" % im.size, im.mode)
        mode = im.mode
        r, g, b, a = im.split()
except IOError:
    pass

image_new = Image.merge(mode, (r, g, 0, a))

# save the doctored image 
image_new.save('soduko_new.png', "PNG")
# Out:
# PNG 599 x 646 RGBA
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-31-738989e926f7> in <module>
#       9     pass
#      10
# ---> 11 image_new = Image.merge(mode, (r, g, 0, a))
#      12
#      13 # save the doctored image
#
# C:\bin\Continuum\Anaconda3\lib\site-packages\PIL\Image.py in merge(mode, bands)
#    2747         raise ValueError("wrong number of bands")
#    2748     for band in bands[1:]:
# -> 2749         if band.mode != getmodetype(mode):
#    2750             raise ValueError("mode mismatch")
#    2751         if band.size != bands[0].size:
#
# AttributeError: 'int' object has no attribute 'mode'

# %%
image_new.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-24-a25384b90331> in <module>
# ----> 1 im.show()
#
# C:\bin\Continuum\Anaconda3\lib\site-packages\PIL\Image.py in show(self, title, command)
#    2014         """
#    2015
# -> 2016         _show(self, title=title, command=command)
#    2017
#    2018     def split(self):
#
# C:\bin\Continuum\Anaconda3\lib\site-packages\PIL\Image.py in _show(image, **options)
#    2874 def _show(image, **options):
#    2875     # override me, as necessary
# -> 2876     _showxv(image, **options)
#    2877
#    2878
#
# C:\bin\Continuum\Anaconda3\lib\site-packages\PIL\Image.py in _showxv(image, title, **options)
#    2879 def _showxv(image, title=None, **options):
#    2880     from . import ImageShow
# -> 2881     ImageShow.show(image, title, **options)
#    2882
#    2883
#
# ...

# %%
from PIL import Image

img = Image.open('sudoku.png')
data = img.getdata()

# Suppress specific bands (e.g. (255, 120, 65) -> (0, 120, 0) for g)
r = [(d[0], 0, 0) for d in data]
g = [(0, d[1], 0) for d in data]
b = [(0, 0, d[2]) for d in data]

img.putdata(r)
img.save('r.png')
img.putdata(g)
img.save('g.png')
img.putdata(b)
img.save('b.png')

# %%
type(data)
# Out:
# ImagingCore

# %%
img = Image.open('b.png')
img_new = skic.rgb2gray(img)

show(img_new)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-36-ee4314612500> in <module>
#       1 img = Image.open('b.png')
# ----> 2 img_new = skic.rgb2gray(img)
#       3
#       4 show(img_new)
#
# C:\bin\Continuum\Anaconda3\lib\site-packages\skimage\color\colorconv.py in rgb2gray(rgb)
#     791     """
#     792
# --> 793     if rgb.ndim == 2:
#     794         return np.ascontiguousarray(rgb)
#     795
#
# AttributeError: 'PngImageFile' object has no attribute 'ndim'

# %%
from PIL import Image
img = Image.open('b.png').convert('LA')
img.save('greyscale.png')
